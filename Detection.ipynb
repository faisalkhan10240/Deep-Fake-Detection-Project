# %%
import cv2
import numpy as np
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
import matplotlib.pyplot as plt 
import matplotlib.image as mpimg

# %%
model = load_model("deepfake_xception.h5")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
def predict_image(img_path):
    img = image.load_img(img_path, target_size=(299, 299))
    x = image.img_to_array(img)/255.0
    x = np.expand_dims(x, axis=0)
    pred = model.predict(x)[0][0]
    print(f"Prediction score: {pred:.4f}")
    if pred < 0.5:
        print("🟢 Real Image Detected")
    else:
        print("🔴 DeepFake Image Detected")

# %%
img = mpimg.imread(r"C:\Users\asus\tf_env\DeepFake_Detection\Info_About_Fake_Img.jpg")
plt.imshow(img)

# %%
img = mpimg.imread(r"C:\Users\asus\tf_env\DeepFake_Detection\DeepFake_RDJ.jpg")
plt.imshow(img)
predict_image(r"C:\Users\asus\tf_env\DeepFake_Detection\DeepFake_RDJ.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Prediction score: 0.7925
# 🔴 DeepFake Image Detected

# %%
img = mpimg.imread(r"C:\Users\asus\tf_env\DeepFake_Detection\Real_RDJ.jpg")
plt.imshow(img)
predict_image(r"C:\Users\asus\tf_env\DeepFake_Detection\Real_RDJ.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# Prediction score: 0.0808
# 🟢 Real Image Detected

# %%
img = mpimg.imread(r"C:\Users\asus\tf_env\DeepFake_Detection\unnamed.jpg")
plt.imshow(img)
predict_image(r"C:\Users\asus\tf_env\DeepFake_Detection\unnamed.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# Prediction score: 0.7348
# 🔴 DeepFake Image Detected

# %%
img = mpimg.imread(r"C:\Users\asus\tf_env\DeepFake_Detection\The_White_House_-_54409525537_(cropped).jpg")
plt.imshow(img)
predict_image(r"C:\Users\asus\tf_env\DeepFake_Detection\The_White_House_-_54409525537_(cropped).jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# Prediction score: 0.3670
# 🟢 Real Image Detected
